# %% [markdown]
# Authour: Md Redwan Hossain Date: 02/08/2025
#
# Objective: Auto annotated images from ToAnnotate folder and moves them to AutoAnnotated fodler. Creates both txt and xml annotation.
# uses master class mapping csv (normalized species matching:ignores case, spaces, underscores, and dashes)  for class id, adds new class mapping if not found.
#
#
#
# Features: - Normalizes folder matching (ignores case, spaces, underscores, and dashes). - Prints clear progress and summary report.

# %%
dataset_root = "./datasets"  # Change if needed
model_path = "./models/ant_detector_yolov12m.pt"
confidence_threshold = 0.4
to_annotate_path = "ToAnnotate"
auto_annotated_path = "AutoAnnotated"
mapping_file_path = "master_class_mapping.csv"

# %%
import os
from pathlib import Path
from backend_AutoAnnotateAndStructre.auto_annotate_auto_structreTo_AutoAnnotated_XML_TXT import run_annotation




if __name__ == "__main__":

    print("=== Ant Auto Annotator (YOLOv12) ===\n")
    print(f"[INFO] Dataset: {dataset_root}")
    print(f"[INFO] Model: {model_path}")
    print(f"[INFO] Confidence: {confidence_threshold}\n")

    try:
        run_annotation(
            #dataset_root,
            model_path,
            to_annotate_path,
            auto_annotated_path,
            mapping_file_path,
            confidence_threshold
        )
    except FileNotFoundError as e:
        print(str(e))
# Out:
# === Ant Auto Annotator (YOLOv12) ===
#
# [INFO] Dataset: ./datasets
# [INFO] Model: ./models/ant_detector_yolov12m.pt
# [INFO] Confidence: 0.4
#
# [INFO] Using model: ./models/ant_detector_yolov12m.pt
# [INFO] Loading YOLOv12m on GPU...
#
# [•] Processing species: sample_ants (ClassID: 117)
# C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# [✓] Annotated 111_3930dd.jpg
# [✓] Annotated 143_e6cd25.jpg
# [✓] Annotated 1_4181d0.jpg
# [✓] Annotated 281_cad03b.jpg
# [✓] Annotated 79_0ba740.jpg
#
# [•] Processing species: Solenopsis_geminata (ClassID: 82)
# [✓] Annotated 20221006_083537(0)_51d60c.jpg
# [✓] Annotated 20221006_083555_f166c2.jpg
# [✓] Annotated 20221006_083611(0)_1c3180.jpg
# [✓] Annotated 20221006_083623_1cea06.jpg
# [✓] Annotated 20221006_083641_8ba446.jpg
# [✓] Annotated 20221006_083707_368b76.jpg
# [✓] Annotated 20221006_083724_c13dba.jpg
# [✓] Annotated 20221006_083744_06c994.jpg
# [✓] Annotated 20221006_083757_f69462.jpg
# [✓] Annotated 20221006_083858_1c831c.jpg
# [✓] Annotated 20221006_083944(0)_ea549b.jpg
# [✓] Annotated 20221006_084010(0)_7d9406.jpg
# [✓] Annotated 20221006_084034_1da1e6.jpg
# [✓] Annotated 20221006_084053_aa0ba5.jpg
# [✓] Annotated 20221006_084119_c1c863.jpg
# [✓] Annotated 20221006_084133_350056.jpg
# [✓] Annotated 20221006_084449(0)_e12bf7.jpg
# [✓] Annotated 20221006_084505_0edd99.jpg
# [✓] Annotated 20221006_084528_e76ae4.jpg
# [✓] Annotated 20221006_084545_5f89a0.jpg
# [✓] Annotated 20221006_084609_703aa9.jpg
# [✓] Annotated 20221006_084636_4a495e.jpg
# [✓] Annotated 20221006_084715(0)_98c590.jpg
# [✓] Annotated 20221006_084728_0fac57.jpg
# [✓] Annotated 20221006_084748_d4abc3.jpg
# [✓] Annotated 20221006_085730_4ed89a.jpg
# [✓] Annotated 20221006_085747_de6f2f.jpg
# [✓] Annotated 20221006_085806_8f9f70.jpg
# [✓] Annotated 20221006_090004_ceda35.jpg
# [✓] Annotated 20221006_090022_9e2783.jpg
# [✓] Annotated 20221006_090059_6920b0.jpg
# [✓] Annotated 20221006_090238(0)_f12d03.jpg
# [✓] Annotated 20221006_090255_19f7ab.jpg
# [✓] Annotated 20221006_090335_174232.jpg
# [✓] Annotated 20221006_090615(0)_7bbd88.jpg
# [✓] Annotated 20221006_090709_f164b9.jpg
# [✓] Annotated IMG_0037_88bbb0.jpg
# [✓] Annotated IMG_1444_25a003.jpg
# [✓] Annotated IMG_2130_e59494.jpg
# [✓] Annotated P1220009_17276e.jpg
# [✓] Annotated P8080002_8a079e.jpg
# [✓] Annotated P8080039_df74ce.jpg
# [✓] Annotated P8080055_aaffb7.jpg
# [✓] Annotated P8080072_069412.jpg
# [✓] Annotated P8080089_58604a.jpg
# [✓] Annotated P8080105_81af8b.jpg
# [✓] Annotated P8090015_8c416c.jpg
# [✓] Annotated P8090045_59a4a4.jpg
# [✓] Annotated P8090061_cebb53.jpg
# [✓] Annotated P8090094_d92f2d.jpg
# [✓] Annotated P8130021_b8333f.jpg
# [✓] Annotated P8130054_7db535.jpg
# [✓] Annotated P8130068_fff7a3.jpg
# [✓] Annotated P8130085_93e6b5.jpg
# [✓] Annotated P8130099_9a02de.jpg
# [✓] Annotated P8130113_b6d978.jpg
# [✓] Annotated P8130127_c25a84.jpg
# [✓] Annotated P8130141_01168d.jpg
# [✓] Annotated P8130155_9e03c2.jpg
# [✓] Annotated P8130169_f8654d.jpg
# [✓] Annotated P8130197_fea293.jpg
# [✓] Annotated P8130211_1fe5a0.jpg
# [✓] Annotated P8130228_2939d6.jpg
# [✓] Annotated P8130246_1280d6.jpg
# [✓] Annotated P8130264_ed8f66.jpg
# [✓] Annotated P8130278_319dc1.jpg
# [✓] Annotated P8130292_04d435.jpg
# [✓] Annotated P8130306_dfa8c6.jpg
# [✓] Annotated P8130320_c65a79.jpg
# [✓] Annotated P8130335_e0c083.jpg
# [✓] Annotated P8130350_f92acd.jpg
# [✓] Annotated P8130367_3561f3.jpg
# [✓] Annotated P8130381_aec159.jpg
# [✓] Annotated P8130395_063b1f.jpg
# [✓] Annotated P8130409_83e9cb.jpg
# [✓] Annotated P8130423_2f9666.jpg
# [✓] Annotated P8130439_eb156b.jpg
# [✓] Annotated P8140001_87f830.jpg
# [✓] Annotated P8140016_ffb811.jpg
# [✓] Annotated P8140045_0827e7.jpg
# [✓] Annotated Solenopsis_geminata_Texas_220511_077_fc5872.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_094_70d171.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_122_f922a3.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_139_19a162.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_159_571439.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_178_c217d9.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_197_7b34ad.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_211_46c8ae.tif
# [✓] Annotated Solenopsis_geminata_Texas_220511_228_f7722d.tif
# [✓] Annotated TFA 017_04c6ff.jpg
#
# [•] Processing species: Wasmannia Auropunctata (ClassID: 105)
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_040_580027.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_054_10bb0f.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_068_c07a93.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_082_1511e9.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_096_da4fe2.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_110_af5e45.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_124_afee01.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_138_1cc395.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_152_c35e5b.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_166_54a11d.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_180_83a04f.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_194_0cb8cf.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_040_83b636.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_040_a06212.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_054_19a279.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_054_5edd38.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_068_cdf727.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_068_f93c48.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_082_b5752e.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_082_b8adc6.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_096_2f47f4.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_096_307fd4.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_110_928bba.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_110_cb79b8.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_124_09d51b.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_124_a31afd.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_138_40a7a7.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_138_831b96.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_152_0cf026.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_152_4bacde.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_166_2fb9f8.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_166_872e66.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_180_40b1ef.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_180_63e10f.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_194_12865d.tif
# [✓] Annotated Wasmannia_auropunctata_Cairns__221021_194_beb9fc.tif
#
# === Summary Report ===
# Total species processed: 3
# Total images annotated: 131
# New species added: None

# %% [markdown]
# Customised iabelImg program
#
# feature: reads from xml, saves both xml and txt, saves the manully cheked annotatio

# %%
# !python CustomLabelImg/labelImg.py

# %% [markdown]
# # Keybord-shortcuts for labelImg
# ![image.png](attachment:6eb1f286-57c8-4d5a-b82c-5a1020cf5bb5.png)

# %% [markdown]
# # Draft

# %%
# !labelImg
# Out:
# Traceback (most recent call last):
#   File "C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\labelImg\labelImg.py", line 1376, in open_next_image
#     self.load_file(filename)
#   File "C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\labelImg\labelImg.py", line 1111, in load_file
#     self.show_bounding_box_from_annotation_file(file_path)
#   File "C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\labelImg\labelImg.py", line 1144, in show_bounding_box_from_annotation_file
#     self.load_yolo_txt_by_filename(txt_path)
#   File "C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\labelImg\labelImg.py", line 1557, in load_yolo_txt_by_filename
#     t_yolo_parse_reader = YoloReader(txt_path, self.image)
#   File "C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\libs\yolo_io.py", line 100, in __init__
#     classes_file = open(self.class_list_path, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\AntBiosecurity\\Ant Annotator\\ant_auto-annotation\\AutoAnnotated\\sample_ants\\sample_ants_Annotations\\TXT_Only\\classes.txt'

# %%
conda install pyqt=5 lxml -c conda-forge
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - nvidia
#  - pytorch
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\AntBiosecurity\anaconda3\envs\yolo_env
#
#   added / updated specs:
#     - lxml
#     - pyqt=5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.8.3   |       h4c7d964_0         151 KB  conda-forge
#     glib-2.84.0                |       h3d4babf_0         566 KB  conda-forge
#     glib-tools-2.84.0          |       h4394cf3_0          95 KB  conda-forge
#     gst-plugins-base-1.24.7    |       hb0a98b8_0         2.0 MB  conda-forge
#     gstreamer-1.24.7           |       h5006eae_0         1.9 MB  conda-forge
#     icu-75.1                   |       he0c23c2_0        13.9 MB  conda-forge
#     krb5-1.21.3                |       hdf4eb48_0         695 KB  conda-forge
#     libclang13-20.1.8          |default_hadf22e1_0        27.0 MB  conda-forge
#     libexpat-2.7.1             |       hac47afa_0         138 KB  conda-forge
#     libglib-2.84.0             |       h7025463_0         3.7 MB  conda-forge
#     libiconv-1.18              |       h135ad9c_1         623 KB  conda-forge
#     libintl-0.22.5             |       h5728263_3          93 KB  conda-forge
#     libintl-devel-0.22.5       |       h5728263_3          40 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       h2466b09_0         819 KB  conda-forge
#     liblzma-5.8.1              |       h2466b09_2         102 KB  conda-forge
#     liblzma-devel-5.8.1        |       h2466b09_2         126 KB  conda-forge
#     libogg-1.3.5               |       h2466b09_1          34 KB  conda-forge
#     libpng-1.6.50              |       h7351971_1         374 KB  conda-forge
#     libsqlite-3.50.4           |       hf5d6505_0         1.2 MB  conda-forge
#     libvorbis-1.3.7            |       h5112557_2         238 KB  conda-forge
#     libxml2-2.13.8             |       h741aa76_1         1.4 MB  conda-forge
#     libxslt-1.1.43             |       h25c3957_0         407 KB  conda-forge
#     libzlib-1.3.1              |       h2466b09_2          54 KB  conda-forge
#     lxml-6.0.0                 |  py310h4b5876d_0         1.1 MB  conda-forge
#     openssl-3.5.2              |       h725018a_0         8.8 MB  conda-forge
#     packaging-25.0             |     pyh29332c3_1          61 KB  conda-forge
#     pcre2-10.44                |       h99c9b8b_2         798 KB  conda-forge
#     ply-3.11                   |     pyhd8ed1ab_3          48 KB  conda-forge
#     pyqt-5.15.11               |  py310h936fe8c_1         3.7 MB  conda-forge
#     pyqt5-sip-12.17.0          |  py310h9e98ed7_1          74 KB  conda-forge
#     python-3.10.18             |h8c5b53a_0_cpython        15.1 MB  conda-forge
#     python_abi-3.10            |          8_cp310           7 KB  conda-forge
#     qt-main-5.15.15            |       h9151539_3        57.1 MB  conda-forge
#     sip-6.10.0                 |  py310h9e98ed7_0         559 KB  conda-forge
#     tk-8.6.13                  |       h2c6b04d_2         3.3 MB  conda-forge
#     toml-0.10.2                |     pyhd8ed1ab_1          22 KB  conda-forge
#     tomli-2.2.1                |     pyhe01879c_2          21 KB  conda-forge
#     xz-5.8.1                   |       h208afaa_2          24 KB  conda-forge
#     xz-tools-5.8.1             |       h2466b09_2          66 KB  conda-forge
#     zlib-1.3.1                 |       h2466b09_2         105 KB  conda-forge
#     zstd-1.5.7                 |       hbeecb71_2         346 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       146.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   glib               conda-forge/win-64::glib-2.84.0-h3d4babf_0
#   glib-tools         conda-forge/win-64::glib-tools-2.84.0-h4394cf3_0
#   gst-plugins-base   conda-forge/win-64::gst-plugins-base-1.24.7-hb0a98b8_0
#   gstreamer          conda-forge/win-64::gstreamer-1.24.7-h5006eae_0
#   icu                conda-forge/win-64::icu-75.1-he0c23c2_0
#   krb5               conda-forge/win-64::krb5-1.21.3-hdf4eb48_0
#   libclang13         conda-forge/win-64::libclang13-20.1.8-default_hadf22e1_0
#   libexpat           conda-forge/win-64::libexpat-2.7.1-hac47afa_0
#   libglib            conda-forge/win-64::libglib-2.84.0-h7025463_0
#   libiconv           conda-forge/win-64::libiconv-1.18-h135ad9c_1
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_3
#   libintl-devel      conda-forge/win-64::libintl-devel-0.22.5-h5728263_3
#   libjpeg-turbo      conda-forge/win-64::libjpeg-turbo-3.1.0-h2466b09_0
#   liblzma            conda-forge/win-64::liblzma-5.8.1-h2466b09_2
#   liblzma-devel      conda-forge/win-64::liblzma-devel-5.8.1-h2466b09_2
#   libogg             conda-forge/win-64::libogg-1.3.5-h2466b09_1
#   libpng             conda-forge/win-64::libpng-1.6.50-h7351971_1
#   libsqlite          conda-forge/win-64::libsqlite-3.50.4-hf5d6505_0
#   libvorbis          conda-forge/win-64::libvorbis-1.3.7-h5112557_2
#   libxml2            conda-forge/win-64::libxml2-2.13.8-h741aa76_1
#   libxslt            conda-forge/win-64::libxslt-1.1.43-h25c3957_0
#   libzlib            conda-forge/win-64::libzlib-1.3.1-h2466b09_2
#   lxml               conda-forge/win-64::lxml-6.0.0-py310h4b5876d_0
#   packaging          conda-forge/noarch::packaging-25.0-pyh29332c3_1
#   pcre2              conda-forge/win-64::pcre2-10.44-h99c9b8b_2
#   ply                conda-forge/noarch::ply-3.11-pyhd8ed1ab_3
#   pyqt               conda-forge/win-64::pyqt-5.15.11-py310h936fe8c_1
#   pyqt5-sip          conda-forge/win-64::pyqt5-sip-12.17.0-py310h9e98ed7_1
#   python_abi         conda-forge/noarch::python_abi-3.10-8_cp310
#   qt-main            conda-forge/win-64::qt-main-5.15.15-h9151539_3
#   sip                conda-forge/win-64::sip-6.10.0-py310h9e98ed7_0
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_1
#   tomli              conda-forge/noarch::tomli-2.2.1-pyhe01879c_2
#   xz-tools           conda-forge/win-64::xz-tools-5.8.1-h2466b09_2
#   zstd               conda-forge/win-64::zstd-1.5.7-hbeecb71_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2025.8.3-h4c7d964_0
#   openssl              pkgs/main::openssl-3.0.16-h3f729d1_0 --> conda-forge::openssl-3.5.2-h725018a_0
#   xz                         pkgs/main::xz-5.6.4-h4754444_1 --> conda-forge::xz-5.8.1-h208afaa_2
#   zlib                    pkgs/main::zlib-1.2.13-h8cc25b3_1 --> conda-forge::zlib-1.3.1-h2466b09_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   python               pkgs/main::python-3.10.18-h981015d_0 --> conda-forge::python-3.10.18-h8c5b53a_0_cpython
#   tk                        pkgs/main::tk-8.6.14-h5e9d12e_1 --> conda-forge::tk-8.6.13-h2c6b04d_2
#
#
#
# Downloading and Extracting Packages: ...working...
# qt-main-5.15.15      | 57.1 MB   |            |   0%
#
# libclang13-20.1.8    | 27.0 MB   |            |   0%
#
#
# python-3.10.18       | 15.1 MB   |            |   0%
#
#
#
# icu-75.1             | 13.9 MB   |            |   0%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    |            |   0%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    |            |   0%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    |            |   0%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    |            |   0%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.21.3          | 695 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 623 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.0          | 566 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.10.0           | 559 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libclang13-20.1.8    | 27.0 MB   |            |   0%
#
#
# python-3.10.18       | 15.1 MB   |            |   1%
#
#
#
# icu-75.1             | 13.9 MB   |            |   0%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    |            |   0%
#
#
# python-3.10.18       | 15.1 MB   | 3          |   3%
#
#
#
# icu-75.1             | 13.9 MB   | 3          |   3%
#
# libclang13-20.1.8    | 27.0 MB   | 2          |   2%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | 2          |   3%
#
#
# python-3.10.18       | 15.1 MB   | 5          |   5%
#
#
#
# icu-75.1             | 13.9 MB   | 6          |   7%
#
# libclang13-20.1.8    | 27.0 MB   | 3          |   4%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | 5          |   5%
# qt-main-5.15.15      | 57.1 MB   |            |   0%
#
#
#
# icu-75.1             | 13.9 MB   | 9          |   9%
#
# libclang13-20.1.8    | 27.0 MB   | 5          |   5%
#
#
# python-3.10.18       | 15.1 MB   | 7          |   7%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | 8          |   9%
# qt-main-5.15.15      | 57.1 MB   |            |   0%
#
#
#
# icu-75.1             | 13.9 MB   | #1         |  12%
#
#
# python-3.10.18       | 15.1 MB   | 8          |   9%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #2         |  12%
#
# libclang13-20.1.8    | 27.0 MB   | 6          |   6%
# qt-main-5.15.15      | 57.1 MB   | 1          |   1%
# qt-main-5.15.15      | 57.1 MB   | 1          |   2%
#
#
# python-3.10.18       | 15.1 MB   | #          |  10%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #4         |  15%
#
#
#
# icu-75.1             | 13.9 MB   | #3         |  14%
#
# libclang13-20.1.8    | 27.0 MB   | 7          |   7%
# qt-main-5.15.15      | 57.1 MB   | 2          |   3%
#
#
# python-3.10.18       | 15.1 MB   | #1         |  12%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #7         |  17%
#
#
#
# icu-75.1             | 13.9 MB   | #5         |  16%
#
# libclang13-20.1.8    | 27.0 MB   | 8          |   8%
#
#
# python-3.10.18       | 15.1 MB   | #3         |  13%
# qt-main-5.15.15      | 57.1 MB   | 3          |   3%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #9         |  20%
#
#
#
# icu-75.1             | 13.9 MB   | #7         |  17%
#
# libclang13-20.1.8    | 27.0 MB   | 8          |   9%
#
#
# python-3.10.18       | 15.1 MB   | #4         |  15%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ##2        |  22%
# qt-main-5.15.15      | 57.1 MB   | 3          |   4%
#
#
#
# icu-75.1             | 13.9 MB   | #9         |  19%
#
# libclang13-20.1.8    | 27.0 MB   | 9          |  10%
#
#
# python-3.10.18       | 15.1 MB   | #6         |  16%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ##4        |  25%
# qt-main-5.15.15      | 57.1 MB   | 4          |   4%
#
#
#
# icu-75.1             | 13.9 MB   | ##         |  21%
#
# libclang13-20.1.8    | 27.0 MB   | #          |  11%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ##7        |  27%
#
#
# python-3.10.18       | 15.1 MB   | #7         |  18%
#
#
#
# icu-75.1             | 13.9 MB   | ##2        |  23%
# qt-main-5.15.15      | 57.1 MB   | 4          |   5%
#
# libclang13-20.1.8    | 27.0 MB   | #1         |  11%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ##9        |  30%
#
#
# python-3.10.18       | 15.1 MB   | #9         |  19%
#
#
#
# icu-75.1             | 13.9 MB   | ##4        |  24%
#
# libclang13-20.1.8    | 27.0 MB   | #2         |  12%
# qt-main-5.15.15      | 57.1 MB   | 5          |   5%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ###2       |  32%
#
#
# python-3.10.18       | 15.1 MB   | ##         |  21%
#
#
#
# icu-75.1             | 13.9 MB   | ##6        |  26%
#
# libclang13-20.1.8    | 27.0 MB   | #3         |  13%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ###4       |  35%
#
#
# python-3.10.18       | 15.1 MB   | ##2        |  23%
# qt-main-5.15.15      | 57.1 MB   | 5          |   6%
#
#
#
# icu-75.1             | 13.9 MB   | ##8        |  28%
#
# libclang13-20.1.8    | 27.0 MB   | #4         |  14%
#
#
# python-3.10.18       | 15.1 MB   | ##4        |  24%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ###7       |  37%
# qt-main-5.15.15      | 57.1 MB   | 6          |   6%
#
#
#
# icu-75.1             | 13.9 MB   | ##9        |  30%
#
# libclang13-20.1.8    | 27.0 MB   | #4         |  15%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ####       |  40%
#
#
# python-3.10.18       | 15.1 MB   | ##5        |  26%
# qt-main-5.15.15      | 57.1 MB   | 6          |   7%
#
#
#
# icu-75.1             | 13.9 MB   | ###1       |  32%
#
# libclang13-20.1.8    | 27.0 MB   | #5         |  16%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ####2      |  43%
#
#
# python-3.10.18       | 15.1 MB   | ##7        |  28%
# qt-main-5.15.15      | 57.1 MB   | 7          |   7%
#
#
#
# icu-75.1             | 13.9 MB   | ###3       |  33%
#
# libclang13-20.1.8    | 27.0 MB   | #6         |  17%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ####5      |  46%
#
#
# python-3.10.18       | 15.1 MB   | ##9        |  29%
# qt-main-5.15.15      | 57.1 MB   | 7          |   8%
#
#
#
# icu-75.1             | 13.9 MB   | ###4       |  35%
#
# libclang13-20.1.8    | 27.0 MB   | #7         |  18%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ####8      |  48%
# qt-main-5.15.15      | 57.1 MB   | 7          |   8%
#
#
# python-3.10.18       | 15.1 MB   | ###        |  31%
#
#
#
# icu-75.1             | 13.9 MB   | ###6       |  37%
#
# libclang13-20.1.8    | 27.0 MB   | #8         |  18%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #####      |  51%
# qt-main-5.15.15      | 57.1 MB   | 8          |   8%
#
#
# python-3.10.18       | 15.1 MB   | ###2       |  32%
#
#
#
# icu-75.1             | 13.9 MB   | ###8       |  39%
#
# libclang13-20.1.8    | 27.0 MB   | #9         |  19%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #####3     |  54%
#
#
# python-3.10.18       | 15.1 MB   | ###3       |  34%
# qt-main-5.15.15      | 57.1 MB   | 8          |   9%
#
#
#
# icu-75.1             | 13.9 MB   | ####       |  40%
#
# libclang13-20.1.8    | 27.0 MB   | ##         |  20%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #####6     |  56%
#
#
# python-3.10.18       | 15.1 MB   | ###5       |  35%
# qt-main-5.15.15      | 57.1 MB   | 9          |   9%
#
#
#
# icu-75.1             | 13.9 MB   | ####1      |  42%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #####8     |  59%
#
# libclang13-20.1.8    | 27.0 MB   | ##1        |  21%
# qt-main-5.15.15      | 57.1 MB   | 9          |  10%
#
#
# python-3.10.18       | 15.1 MB   | ###6       |  37%
#
#
#
# icu-75.1             | 13.9 MB   | ####3      |  44%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ######1    |  62%
#
# libclang13-20.1.8    | 27.0 MB   | ##1        |  22%
# qt-main-5.15.15      | 57.1 MB   | #          |  10%
#
#
# python-3.10.18       | 15.1 MB   | ###8       |  38%
#
#
#
# icu-75.1             | 13.9 MB   | ####5      |  45%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ######4    |  64%
#
# libclang13-20.1.8    | 27.0 MB   | ##2        |  23%
# qt-main-5.15.15      | 57.1 MB   | #          |  11%
#
#
# python-3.10.18       | 15.1 MB   | ###9       |  40%
#
#
#
# icu-75.1             | 13.9 MB   | ####7      |  47%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ######7    |  67%
#
# libclang13-20.1.8    | 27.0 MB   | ##3        |  24%
#
#
# python-3.10.18       | 15.1 MB   | ####1      |  41%
# qt-main-5.15.15      | 57.1 MB   | #          |  11%
#
#
#
# icu-75.1             | 13.9 MB   | ####8      |  49%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #######    |  70%
#
# libclang13-20.1.8    | 27.0 MB   | ##4        |  24%
#
#
# python-3.10.18       | 15.1 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #1         |  11%
#
#
#
# icu-75.1             | 13.9 MB   | #####      |  51%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #######3   |  73%
#
# libclang13-20.1.8    | 27.0 MB   | ##5        |  25%
#
#
# python-3.10.18       | 15.1 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #1         |  12%
#
#
#
# icu-75.1             | 13.9 MB   | #####2     |  52%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #######5   |  76%
#
# libclang13-20.1.8    | 27.0 MB   | ##6        |  26%
#
#
# python-3.10.18       | 15.1 MB   | ####6      |  46%
# qt-main-5.15.15      | 57.1 MB   | #2         |  12%
#
#
#
# icu-75.1             | 13.9 MB   | #####4     |  54%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #######8   |  79%
#
# libclang13-20.1.8    | 27.0 MB   | ##7        |  27%
#
#
# python-3.10.18       | 15.1 MB   | ####7      |  48%
# qt-main-5.15.15      | 57.1 MB   | #2         |  13%
#
#
#
# icu-75.1             | 13.9 MB   | #####5     |  56%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ########1  |  82%
#
# libclang13-20.1.8    | 27.0 MB   | ##8        |  28%
#
#
# python-3.10.18       | 15.1 MB   | ####9      |  49%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
# icu-75.1             | 13.9 MB   | #####7     |  57%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ########4  |  85%
#
# libclang13-20.1.8    | 27.0 MB   | ##8        |  29%
#
#
# python-3.10.18       | 15.1 MB   | #####      |  51%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
# icu-75.1             | 13.9 MB   | #####9     |  59%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ########7  |  87%
#
# libclang13-20.1.8    | 27.0 MB   | ##9        |  30%
#
#
# python-3.10.18       | 15.1 MB   | #####2     |  52%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
#
#
#
# icu-75.1             | 13.9 MB   | ######     |  61%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #########  |  90%
#
# libclang13-20.1.8    | 27.0 MB   | ###        |  31%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
# python-3.10.18       | 15.1 MB   | #####3     |  54%
#
#
#
# icu-75.1             | 13.9 MB   | ######2    |  63%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #########3 |  93%
#
# libclang13-20.1.8    | 27.0 MB   | ###1       |  32%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
# python-3.10.18       | 15.1 MB   | #####5     |  55%
#
#
#
# icu-75.1             | 13.9 MB   | ######4    |  64%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #########5 |  96%
#
# libclang13-20.1.8    | 27.0 MB   | ###2       |  32%
#
#
# python-3.10.18       | 15.1 MB   | #####6     |  57%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
# icu-75.1             | 13.9 MB   | ######6    |  66%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | #########8 |  99%
#
# libclang13-20.1.8    | 27.0 MB   | ###3       |  33%
#
#
# python-3.10.18       | 15.1 MB   | #####8     |  58%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
# icu-75.1             | 13.9 MB   | ######8    |  68%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | ###4       |  34%
#
#
# python-3.10.18       | 15.1 MB   | ######     |  60%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
#
# icu-75.1             | 13.9 MB   | #######    |  71%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    |            |   0%
#
# libclang13-20.1.8    | 27.0 MB   | ###5       |  35%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
#
# python-3.10.18       | 15.1 MB   | ######2    |  62%
#
#
#
# icu-75.1             | 13.9 MB   | #######2   |  72%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | 5          |   5%
#
# libclang13-20.1.8    | 27.0 MB   | ###6       |  36%
#
#
# python-3.10.18       | 15.1 MB   | ######3    |  64%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
# icu-75.1             | 13.9 MB   | #######4   |  74%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | 9          |  10%
#
# libclang13-20.1.8    | 27.0 MB   | ###7       |  37%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
# python-3.10.18       | 15.1 MB   | ######5    |  65%
#
#
#
# icu-75.1             | 13.9 MB   | #######6   |  76%
#
#
#
#
# openssl-3.5.2        | 8.8 MB    | ########## | 100%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | #4         |  15%
#
# libclang13-20.1.8    | 27.0 MB   | ###8       |  38%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
# python-3.10.18       | 15.1 MB   | ######7    |  67%
#
#
#
# icu-75.1             | 13.9 MB   | #######8   |  78%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | #9         |  19%
#
# libclang13-20.1.8    | 27.0 MB   | ###9       |  39%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
# python-3.10.18       | 15.1 MB   | ######9    |  69%
#
#
#
# icu-75.1             | 13.9 MB   | #######9   |  80%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ##4        |  24%
#
# libclang13-20.1.8    | 27.0 MB   | ###9       |  40%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
# python-3.10.18       | 15.1 MB   | #######    |  71%
#
#
#
# icu-75.1             | 13.9 MB   | ########1  |  82%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ###        |  30%
#
# libclang13-20.1.8    | 27.0 MB   | ####       |  41%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
# python-3.10.18       | 15.1 MB   | #######2   |  73%
#
#
#
# icu-75.1             | 13.9 MB   | ########3  |  84%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ###6       |  36%
#
# libclang13-20.1.8    | 27.0 MB   | ####1      |  42%
# qt-main-5.15.15      | 57.1 MB   | #9         |  19%
#
#
# python-3.10.18       | 15.1 MB   | #######4   |  74%
#
#
#
# icu-75.1             | 13.9 MB   | ########5  |  86%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ####1      |  42%
#
# libclang13-20.1.8    | 27.0 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #9         |  20%
#
#
#
# icu-75.1             | 13.9 MB   | ########7  |  87%
#
#
# python-3.10.18       | 15.1 MB   | #######5   |  76%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ####8      |  48%
#
# libclang13-20.1.8    | 27.0 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | ##         |  20%
#
#
# python-3.10.18       | 15.1 MB   | #######7   |  78%
#
#
#
# icu-75.1             | 13.9 MB   | ########9  |  89%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | #####4     |  55%
#
# libclang13-20.1.8    | 27.0 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | ##         |  20%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ######1    |  61%
#
#
# python-3.10.18       | 15.1 MB   | #######9   |  79%
#
#
#
# icu-75.1             | 13.9 MB   | #########  |  91%
#
# libclang13-20.1.8    | 27.0 MB   | ####5      |  46%
# qt-main-5.15.15      | 57.1 MB   | ##         |  21%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ######8    |  68%
#
#
# python-3.10.18       | 15.1 MB   | ########   |  81%
#
#
#
# icu-75.1             | 13.9 MB   | #########2 |  93%
#
# libclang13-20.1.8    | 27.0 MB   | ####6      |  47%
# qt-main-5.15.15      | 57.1 MB   | ##1        |  21%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | #######5   |  75%
#
#
# python-3.10.18       | 15.1 MB   | ########2  |  82%
#
#
#
# icu-75.1             | 13.9 MB   | #########4 |  94%
#
# libclang13-20.1.8    | 27.0 MB   | ####7      |  48%
# qt-main-5.15.15      | 57.1 MB   | ##1        |  22%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ########2  |  82%
#
#
# python-3.10.18       | 15.1 MB   | ########3  |  84%
#
#
#
# icu-75.1             | 13.9 MB   | #########5 |  96%
#
# libclang13-20.1.8    | 27.0 MB   | ####8      |  49%
# qt-main-5.15.15      | 57.1 MB   | ##2        |  22%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ########8  |  89%
#
#
# python-3.10.18       | 15.1 MB   | ########5  |  85%
#
#
#
# icu-75.1             | 13.9 MB   | #########7 |  97%
#
# libclang13-20.1.8    | 27.0 MB   | ####9      |  49%
# qt-main-5.15.15      | 57.1 MB   | ##2        |  23%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | #########5 |  96%
#
#
# python-3.10.18       | 15.1 MB   | ########6  |  87%
#
#
#
# icu-75.1             | 13.9 MB   | #########9 |  99%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | #####      |  50%
# qt-main-5.15.15      | 57.1 MB   | ##2        |  23%
#
#
# python-3.10.18       | 15.1 MB   | ########8  |  89%
#
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    |            |   0%
#
# libclang13-20.1.8    | 27.0 MB   | #####1     |  52%
# qt-main-5.15.15      | 57.1 MB   | ##3        |  24%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    |            |   0%
#
#
# python-3.10.18       | 15.1 MB   | #########  |  91%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | 5          |   6%
# qt-main-5.15.15      | 57.1 MB   | ##4        |  24%
#
# libclang13-20.1.8    | 27.0 MB   | #####2     |  53%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | 7          |   7%
#
#
# python-3.10.18       | 15.1 MB   | #########2 |  92%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | #1         |  11%
# qt-main-5.15.15      | 57.1 MB   | ##4        |  25%
#
# libclang13-20.1.8    | 27.0 MB   | #####3     |  54%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #4         |  14%
#
#
# python-3.10.18       | 15.1 MB   | #########4 |  94%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | #6         |  17%
# qt-main-5.15.15      | 57.1 MB   | ##5        |  25%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ##2        |  22%
#
# libclang13-20.1.8    | 27.0 MB   | #####4     |  55%
#
#
# python-3.10.18       | 15.1 MB   | #########5 |  96%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ##3        |  23%
# qt-main-5.15.15      | 57.1 MB   | ##5        |  26%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ###        |  30%
#
# libclang13-20.1.8    | 27.0 MB   | #####5     |  56%
#
#
# python-3.10.18       | 15.1 MB   | #########7 |  97%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ##8        |  29%
# qt-main-5.15.15      | 57.1 MB   | ##6        |  26%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ###8       |  39%
#
# libclang13-20.1.8    | 27.0 MB   | #####6     |  57%
#
#
# python-3.10.18       | 15.1 MB   | #########8 |  99%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ###5       |  35%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ####7      |  47%
# qt-main-5.15.15      | 57.1 MB   | ##6        |  27%
#
# libclang13-20.1.8    | 27.0 MB   | #####7     |  57%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ####2      |  43%
#
#
# python-3.10.18       | 15.1 MB   | ########## | 100%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #####6     |  57%
# qt-main-5.15.15      | 57.1 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    |            |   1%
#
# libclang13-20.1.8    | 27.0 MB   | #####8     |  58%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ####9      |  49%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######6    |  66%
#
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ##7        |  28%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | 8          |   9%
#
# libclang13-20.1.8    | 27.0 MB   | #####9     |  59%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | #####5     |  56%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######4   |  75%
# qt-main-5.15.15      | 57.1 MB   | ##8        |  28%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | #7         |  17%
#
# libclang13-20.1.8    | 27.0 MB   | ######     |  60%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ######2    |  63%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########3  |  83%
# qt-main-5.15.15      | 57.1 MB   | ##8        |  29%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ##7        |  28%
#
# libclang13-20.1.8    | 27.0 MB   | ######1    |  61%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ######9    |  70%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########1 |  91%
# qt-main-5.15.15      | 57.1 MB   | ##8        |  29%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ###7       |  37%
#
# libclang13-20.1.8    | 27.0 MB   | ######1    |  62%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########9 |  99%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ########4  |  84%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ####8      |  48%
#
# libclang13-20.1.8    | 27.0 MB   | ######2    |  63%
# qt-main-5.15.15      | 57.1 MB   | ##9        |  29%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    |            |   1%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | #####8     |  59%
# qt-main-5.15.15      | 57.1 MB   | ##9        |  30%
#
# libclang13-20.1.8    | 27.0 MB   | ######3    |  64%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | 9          |  10%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ######9    |  69%
#
# libclang13-20.1.8    | 27.0 MB   | ######4    |  65%
# qt-main-5.15.15      | 57.1 MB   | ###        |  30%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | #########9 | 100%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ###1       |  32%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ########7  |  87%
#
# libclang13-20.1.8    | 27.0 MB   | ######5    |  66%
# qt-main-5.15.15      | 57.1 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ####4      |  45%
#
# libclang13-20.1.8    | 27.0 MB   | ######6    |  67%
# qt-main-5.15.15      | 57.1 MB   | ###1       |  31%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | 1          |   1%
#
# libclang13-20.1.8    | 27.0 MB   | ######7    |  68%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | #####7     |  58%
# qt-main-5.15.15      | 57.1 MB   | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | ####7      |  47%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | ##         |  20%
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ###1       |  32%
#
# libclang13-20.1.8    | 27.0 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | ######7    |  68%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | ####1      |  42%
# qt-main-5.15.15      | 57.1 MB   | ###2       |  32%
#
# libclang13-20.1.8    | 27.0 MB   | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | #####9     |  60%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ########   |  80%
# qt-main-5.15.15      | 57.1 MB   | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | ########1  |  81%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    | 1          |   1%
# qt-main-5.15.15      | 57.1 MB   | ###3       |  33%
#
# libclang13-20.1.8    | 27.0 MB   | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    | ###4       |  35%
# qt-main-5.15.15      | 57.1 MB   | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    | 2          |   2%
#
# libclang13-20.1.8    | 27.0 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    | ######     |  61%
# qt-main-5.15.15      | 57.1 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    | ##2        |  22%
#
# libclang13-20.1.8    | 27.0 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    | ########5  |  86%
# qt-main-5.15.15      | 57.1 MB   | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    | #####4     |  54%
#
# libclang13-20.1.8    | 27.0 MB   | #######4   |  75%
# qt-main-5.15.15      | 57.1 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | #########7 |  98%
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.21.3          | 695 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    | ########4  |  84%
#
# libclang13-20.1.8    | 27.0 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 623 KB    | 2          |   3%
# qt-main-5.15.15      | 57.1 MB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.21.3          | 695 KB    | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 623 KB    | ####8      |  49%
# qt-main-5.15.15      | 57.1 MB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.21.3          | 695 KB    | #######8   |  78%
#
# libclang13-20.1.8    | 27.0 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Note: you may need to restart the kernel to use updated packages.
#
# glib-2.84.0          | 566 KB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 623 KB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.21.3          | 695 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 623 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.10.0           | 559 KB    | 2          |   3%
#
# libclang13-20.1.8    | 27.0 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.0          | 566 KB    | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | ###7       |  37%
#
# libclang13-20.1.8    | 27.0 MB   | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.10.0           | 559 KB    | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.0          | 566 KB    | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libclang13-20.1.8    | 27.0 MB   | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.10.0           | 559 KB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.0          | 566 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.10.0           | 559 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ###8       |  38%
#
# libclang13-20.1.8    | 27.0 MB   | ########4  |  85%
# qt-main-5.15.15      | 57.1 MB   | ###8       |  39%
#
# libclang13-20.1.8    | 27.0 MB   | ########6  |  86%
# qt-main-5.15.15      | 57.1 MB   | ###9       |  39%
#
# libclang13-20.1.8    | 27.0 MB   | ########7  |  88%
# qt-main-5.15.15      | 57.1 MB   | ####       |  40%
#
# libclang13-20.1.8    | 27.0 MB   | ########9  |  89%
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ####       |  41%
#
# libclang13-20.1.8    | 27.0 MB   | #########  |  91%
# qt-main-5.15.15      | 57.1 MB   | ####1      |  42%
#
# libclang13-20.1.8    | 27.0 MB   | #########2 |  92%
# qt-main-5.15.15      | 57.1 MB   | ####2      |  42%
#
# libclang13-20.1.8    | 27.0 MB   | #########3 |  94%
# qt-main-5.15.15      | 57.1 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | #########5 |  96%
# qt-main-5.15.15      | 57.1 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.50.4     | 1.2 MB    | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | #########7 |  97%
# qt-main-5.15.15      | 57.1 MB   | ####5      |  45%
#
# libclang13-20.1.8    | 27.0 MB   | #########9 |  99%
# qt-main-5.15.15      | 57.1 MB   | ####6      |  46%
# qt-main-5.15.15      | 57.1 MB   | ####8      |  48%
# qt-main-5.15.15      | 57.1 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-6.0.0           | 1.1 MB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | #####1     |  52%
#
# libclang13-20.1.8    | 27.0 MB   | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
# gstreamer-1.24.7     | 1.9 MB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | #####7     |  58%
# qt-main-5.15.15      | 57.1 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.21.3          | 695 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ######1    |  62%
# qt-main-5.15.15      | 57.1 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 623 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 798 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ######9    |  70%
# qt-main-5.15.15      | 57.1 MB   | #######1   |  72%
# qt-main-5.15.15      | 57.1 MB   | #######3   |  74%
# qt-main-5.15.15      | 57.1 MB   | #######5   |  76%
# qt-main-5.15.15      | 57.1 MB   | #######7   |  78%
# qt-main-5.15.15      | 57.1 MB   | #######9   |  80%
# qt-main-5.15.15      | 57.1 MB   | ########1  |  82%
# qt-main-5.15.15      | 57.1 MB   | ########3  |  84%
# qt-main-5.15.15      | 57.1 MB   | ########6  |  86%
# qt-main-5.15.15      | 57.1 MB   | ########8  |  88%
# qt-main-5.15.15      | 57.1 MB   | #########  |  91%
# qt-main-5.15.15      | 57.1 MB   | #########2 |  93%
# qt-main-5.15.15      | 57.1 MB   | #########4 |  95%
# qt-main-5.15.15      | 57.1 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.0          | 566 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
# python-3.10.18       | 15.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.10.0           | 559 KB    | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ########## | 100%
#
# libclang13-20.1.8    | 27.0 MB   | ########## | 100%
# qt-main-5.15.15      | 57.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !git clone https://github.com/heartexlabs/labelImg.git
# Out:
# [WinError 2] The system cannot find the file specified: 'CustomlabelImg'
# C:\Users\AntBiosecurity\Ant Annotator\ant_auto-annotation
# fatal: destination path 'labelImg' already exists and is not an empty directory.
# C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# %cd CustomlabelImg
# Out:
# C:\Users\AntBiosecurity\Ant Annotator\ant_auto-annotation\CustomlabelImg
# C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pyrcc5 -o libs/resources.py resources.qrc

# %%
# !python CustomLabelImg/labelImg.py# "C:\Users\AntBiosecurity\Ant Annotator\ant_auto-annotation\CustomLabelImg\labelImg.py"
# Out:
# python: can't open file 'C:\\Users\\AntBiosecurity\\Ant Annotator\\ant_auto-annotation\\CustomLabelImg\\CustomLabelImg\\labelImg.py#': [Errno 2] No such file or directory

# %%
cd
# Out:
# C:\Users\AntBiosecurity
# C:\Users\AntBiosecurity\anaconda3\envs\yolo_env\lib\site-packages\IPython\core\magics\osm.py:428: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
! pip install pickleshare
# Out:
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare
# Successfully installed pickleshare-0.7.5

# %%
# %cd CustomLabelImg
# !pyrcc5 -o libs/resources.py resources.qrc
# !python labelImg.py
# Out:
# C:\Users\AntBiosecurity\Ant Annotator\ant_auto-annotation\CustomLabelImg
# QObject::moveToThread: Current thread (0x1f9bc9ec560) is not the object's thread (0x1f9c06f5470).
# Cannot move to target thread (0x1f9bc9ec560)
#
# qt.qpa.plugin: Could not load the Qt platform plugin "windows" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: minimal, offscreen, webgl, windows.

# %%
# !python -c "from PyQt5.QtWidgets import QApplication, QLabel; import sys; app=QApplication(sys.argv); w=QLabel('Qt OK'); w.show(); app.exec_()"
# Out:
# QObject::moveToThread: Current thread (0x21059443300) is not the object's thread (0x2105cb514e0).
# Cannot move to target thread (0x21059443300)
#
# qt.qpa.plugin: Could not load the Qt platform plugin "windows" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: minimal, offscreen, webgl, windows.

# %%
# !pip uninstall -y PyQt5 PyQt5-Qt5 PyQt5-sip  || rem ok if nothing
# Out:
# Found existing installation: PyQt5 5.15.11
# Uninstalling PyQt5-5.15.11:
#   Successfully uninstalled PyQt5-5.15.11
# Found existing installation: PyQt5-Qt5 5.15.2
# Uninstalling PyQt5-Qt5-5.15.2:
#   Successfully uninstalled PyQt5-Qt5-5.15.2
# Found existing installation: PyQt5_sip 12.17.0
# Uninstalling PyQt5_sip-12.17.0:
#   Successfully uninstalled PyQt5_sip-12.17.0

# %%
conda install -c conda-forge pyqt=5 qt-main lxml -y
# Out:
# Channels:
#  - conda-forge
#  - nvidia
#  - pytorch
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\AntBiosecurity\anaconda3\envs\yolo_env
#
#   added / updated specs:
#     - lxml
#     - pyqt=5
#     - qt-main
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     glib-2.84.3                |       h36503ca_0         561 KB  conda-forge
#     glib-tools-2.84.3          |       he647baa_0          96 KB  conda-forge
#     gst-plugins-base-1.24.11   |       h3fe0a9e_0         4.0 MB  conda-forge
#     gstreamer-1.24.11          |       h233a61a_0         3.0 MB  conda-forge
#     libffi-3.4.6               |       h537db12_1          44 KB  conda-forge
#     libglib-2.84.3             |       h1c1036b_0         3.6 MB  conda-forge
#     pcre2-10.45                |       h99c9b8b_0        1016 KB  conda-forge
#     qt-main-5.15.15            |       h9151539_4        57.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        69.3 MB
#
# The following packages will be UPDATED:
#
#   glib                                    2.84.0-h3d4babf_0 --> 2.84.3-h36503ca_0
#   glib-tools                              2.84.0-h4394cf3_0 --> 2.84.3-he647baa_0
#   gst-plugins-base                        1.24.7-hb0a98b8_0 --> 1.24.11-h3fe0a9e_0
#   gstreamer                               1.24.7-h5006eae_0 --> 1.24.11-h233a61a_0
#   libffi                 pkgs/main::libffi-3.4.4-hd77b12b_1 --> conda-forge::libffi-3.4.6-h537db12_1
#   libglib                                 2.84.0-h7025463_0 --> 2.84.3-h1c1036b_0
#   pcre2                                    10.44-h99c9b8b_2 --> 10.45-h99c9b8b_0
#   qt-main                                5.15.15-h9151539_3 --> 5.15.15-h9151539_4
#
#
#
# Downloading and Extracting Packages: ...working...
# qt-main-5.15.15      | 57.0 MB   |            |   0%
#
# gst-plugins-base-1.2 | 4.0 MB    |            |   0%
#
#
# libglib-2.84.3       | 3.6 MB    |            |   0%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    |            |   0%
#
#
#
#
# pcre2-10.45          | 1016 KB   |            |   0%
#
#
#
#
#
# glib-2.84.3          | 561 KB    |            |   0%
#
#
#
#
#
#
# glib-tools-2.84.3    | 96 KB     |            |   0%
#
#
#
#
#
#
#
# libffi-3.4.6         | 44 KB     |            |   0%
#
#
# libglib-2.84.3       | 3.6 MB    | 4          |   4%
# qt-main-5.15.15      | 57.0 MB   |            |   0%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    |            |   1%
#
#
#
#
# pcre2-10.45          | 1016 KB   | 1          |   2%
#
#
# libglib-2.84.3       | 3.6 MB    | #1         |  12%
#
# gst-plugins-base-1.2 | 4.0 MB    |            |   0%
# qt-main-5.15.15      | 57.0 MB   | 1          |   1%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | #          |  10%
#
#
#
#
# pcre2-10.45          | 1016 KB   | ##8        |  28%
#
# gst-plugins-base-1.2 | 4.0 MB    | 2          |   3%
#
#
# libglib-2.84.3       | 3.6 MB    | #9         |  20%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | #5         |  16%
#
#
#
#
# pcre2-10.45          | 1016 KB   | ########5  |  85%
# qt-main-5.15.15      | 57.0 MB   | 1          |   2%
#
# gst-plugins-base-1.2 | 4.0 MB    | #3         |  14%
#
#
# libglib-2.84.3       | 3.6 MB    | ##6        |  26%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ##4        |  24%
# qt-main-5.15.15      | 57.0 MB   | 1          |   2%
#
# gst-plugins-base-1.2 | 4.0 MB    | ##5        |  25%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ###4       |  34%
#
#
# libglib-2.84.3       | 3.6 MB    | ###2       |  32%
# qt-main-5.15.15      | 57.0 MB   | 2          |   2%
#
# gst-plugins-base-1.2 | 4.0 MB    | ###7       |  38%
#
#
#
#
# pcre2-10.45          | 1016 KB   | ########## | 100%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ####3      |  43%
#
#
# libglib-2.84.3       | 3.6 MB    | ###8       |  39%
#
#
#
#
#
# glib-2.84.3          | 561 KB    | 2          |   3%
# qt-main-5.15.15      | 57.0 MB   | 2          |   3%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | #####1     |  51%
#
#
#
#
#
# glib-2.84.3          | 561 KB    | #########6 |  97%
#
# gst-plugins-base-1.2 | 4.0 MB    | ####6      |  47%
#
#
# libglib-2.84.3       | 3.6 MB    | ####4      |  45%
#
#
#
#
#
# glib-2.84.3          | 561 KB    | ########## | 100%
# qt-main-5.15.15      | 57.0 MB   | 3          |   3%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ######     |  60%
#
#
#
#
#
#
# glib-tools-2.84.3    | 96 KB     | #6         |  17%
#
#
#
#
#
#
# glib-tools-2.84.3    | 96 KB     | ########## | 100%
#
#
# libglib-2.84.3       | 3.6 MB    | ####9      |  50%
#
# gst-plugins-base-1.2 | 4.0 MB    | #####7     |  57%
# qt-main-5.15.15      | 57.0 MB   | 3          |   4%
#
#
#
#
#
#
#
# libffi-3.4.6         | 44 KB     | ###6       |  36%
#
#
#
#
#
#
#
# libffi-3.4.6         | 44 KB     | ########## | 100%
#
#
#
#
#
#
# glib-tools-2.84.3    | 96 KB     | ########## | 100%
#
#
#
#
#
#
# glib-tools-2.84.3    | 96 KB     | ########## | 100%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ######9    |  69%
#
#
# libglib-2.84.3       | 3.6 MB    | #####6     |  57%
#
# gst-plugins-base-1.2 | 4.0 MB    | ######7    |  68%
#
#
#
#
#
#
#
# libffi-3.4.6         | 44 KB     | ########## | 100%
#
#
#
#
#
#
#
# libffi-3.4.6         | 44 KB     | ########## | 100%
# qt-main-5.15.15      | 57.0 MB   | 4          |   4%
#
#
#
#
# pcre2-10.45          | 1016 KB   | ########## | 100%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ########2  |  83%
#
#
# libglib-2.84.3       | 3.6 MB    | ######2    |  62%
#
# gst-plugins-base-1.2 | 4.0 MB    | #######6   |  76%
# qt-main-5.15.15      | 57.0 MB   | 4          |   5%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | #########3 |  93%
#
#
# libglib-2.84.3       | 3.6 MB    | ######8    |  69%
#
# gst-plugins-base-1.2 | 4.0 MB    | ########5  |  85%
# qt-main-5.15.15      | 57.0 MB   | 4          |   5%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ########## | 100%
#
#
# libglib-2.84.3       | 3.6 MB    | #######7   |  78%
#
# gst-plugins-base-1.2 | 4.0 MB    | #########7 |  98%
# qt-main-5.15.15      | 57.0 MB   | 5          |   6%
#
# gst-plugins-base-1.2 | 4.0 MB    | ########## | 100%
#
#
#
#
#
# glib-2.84.3          | 561 KB    | ########## | 100%
#
#
# libglib-2.84.3       | 3.6 MB    | ########9  |  90%
# qt-main-5.15.15      | 57.0 MB   | 6          |   7%
#
#
# libglib-2.84.3       | 3.6 MB    | ########## | 100%
#
#
# libglib-2.84.3       | 3.6 MB    | ########## | 100%
# qt-main-5.15.15      | 57.0 MB   | 7          |   8%
# qt-main-5.15.15      | 57.0 MB   | 9          |  10%
# qt-main-5.15.15      | 57.0 MB   | #1         |  12%
#
#
#
# gstreamer-1.24.11    | 3.0 MB    | ########## | 100%
# qt-main-5.15.15      | 57.0 MB   | #3         |  14%
# qt-main-5.15.15      | 57.0 MB   | #5         |  16%
# qt-main-5.15.15      | 57.0 MB   | #7         |  18%
# qt-main-5.15.15      | 57.0 MB   | #9         |  20%
#
#
# libglib-2.84.3       | 3.6 MB    | ########## | 100%
#
# gst-plugins-base-1.2 | 4.0 MB    | ########## | 100%
# qt-main-5.15.15      | 57.0 MB   | ##1        |  21%
# qt-main-5.15.15      | 57.0 MB   | ##3        |  23%
# qt-main-5.15.15      | 57.0 MB   | ##5        |  25%
# qt-main-5.15.15      | 57.0 MB   | ##6        |  27%
# qt-main-5.15.15      | 57.0 MB   | ##8        |  29%
# qt-main-5.15.15      | 57.0 MB   | ###        |  31%
# qt-main-5.15.15      | 57.0 MB   | ###2       |  33%
# qt-main-5.15.15      | 57.0 MB   | ###4       |  35%
# qt-main-5.15.15      | 57.0 MB   | ###6       |  37%
# qt-main-5.15.15      | 57.0 MB   | ###8       |  39%
# qt-main-5.15.15      | 57.0 MB   | ####       |  41%
# qt-main-5.15.15      | 57.0 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.0 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.0 MB   | ####6      |  47%
# qt-main-5.15.15      | 57.0 MB   | ####8      |  49%
# qt-main-5.15.15      | 57.0 MB   | #####      |  51%
# qt-main-5.15.15      | 57.0 MB   | #####2     |  53%
# qt-main-5.15.15      | 57.0 MB   | #####4     |  55%
# qt-main-5.15.15      | 57.0 MB   | #####6     |  57%
# qt-main-5.15.15      | 57.0 MB   | #####8     |  59%
# qt-main-5.15.15      | 57.0 MB   | ######1    |  61%
# qt-main-5.15.15      | 57.0 MB   | ######3    |  63%
# qt-main-5.15.15      | 57.0 MB   | ######5    |  65%
# qt-main-5.15.15      | 57.0 MB   | ######7    |  67%
# qt-main-5.15.15      | 57.0 MB   | ######9    |  69%
# qt-main-5.15.15      | 57.0 MB   | #######1   |  71%
# qt-main-5.15.15      | 57.0 MB   | #######3   |  73%
# qt-main-5.15.15      | 57.0 MB   | #######5   |  75%
# qt-main-5.15.15      | 57.0 MB   | #######7   |  77%
# qt-main-5.15.15      | 57.0 MB   | #######9   |  79%
# qt-main-5.15.15      | 57.0 MB   | ########1  |  81%
# qt-main-5.15.15      | 57.0 MB   | ########3  |  83%
# qt-main-5.15.15      | 57.0 MB   | ########5  |  85%
# qt-main-5.15.15      | 57.0 MB   | ########7  |  87%
# qt-main-5.15.15      | 57.0 MB   | ########9  |  89%
# qt-main-5.15.15      | 57.0 MB   | #########1 |  91%
# qt-main-5.15.15      | 57.0 MB   | #########3 |  93%
# qt-main-5.15.15      | 57.0 MB   | #########5 |  95%
# qt-main-5.15.15      | 57.0 MB   | #########7 |  97%
# qt-main-5.15.15      | 57.0 MB   | #########9 |  99%
# qt-main-5.15.15      | 57.0 MB   | ########## | 100%
# qt-main-5.15.15      | 57.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, sys, pathlib
prefix = sys.prefix
os.environ["QT_PLUGIN_PATH"] = str(pathlib.Path(prefix, "Library", "plugins"))
os.environ["QT_QPA_PLATFORM_PLUGIN_PATH"] = str(pathlib.Path(prefix, "Library", "plugins", "platforms"))
# %gui qt
# Out:
# ERROR:root:
#     Could not load requested Qt binding. Please ensure that
#     PyQt4 >= 4.7, PyQt5, PyQt6, PySide >= 1.0.3, PySide2, or
#     PySide6 is available, and only one is imported per session.
#
#     Currently-imported Qt library:                              None
#     PyQt5 available (requires QtCore, QtGui, QtSvg, QtWidgets): False
#     PyQt6 available (requires QtCore, QtGui, QtSvg, QtWidgets): False
#     PySide2 installed:                                          False
#     PySide6 installed:                                          False
#     Tried to load:                                              ['pyqtdefault', 'pyqt6', 'pyside6', 'pyqt5', 'pyside2']

# %%
# !pip install

# %% [markdown]
# ##  Keybord-shortcuts for labelImg
# ![image.png](attachment:6eb1f286-57c8-4d5a-b82c-5a1020cf5bb5.png)

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
dataset_root = "./Dataset"  # Change if needed
model_path = "./models/ant_detector_yolov12m.pt"
confidence_threshold = 0.4
to_annotate_path = "./ToAnnotated"
auto_annotated_path = "./AutoAnnotated"
mapping_file_path = "./master_class_mapping.xlsx"

# %%
import os
from auto_annotation_yolov12 import run_annotation

if __name__ == "__main__":

    print("=== Ant Auto Annotator (YOLOv12) ===\n")
    print(f"[INFO] Dataset: {dataset_root}")
    print(f"[INFO] Model: {model_path}")
    print(f"[INFO] Confidence: {confidence_threshold}\n")

    try:
        run_annotation(dataset_root, model_path, confidence, to_annotate_path, auto_annotated_path, mapping_file_path)
    except FileNotFoundError as e:
        print(str(e))
        print("[!] Please place master_class_mapping.xlsx in the dataset root before running.")
# Out:
# === Ant Auto Annotator (YOLOv12) ===
#
# [INFO] Dataset: ./Dataset
# [INFO] Model: ./models/ant_detector_yolov12m.pt
# [INFO] Confidence: 0.4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       9 print(f"[INFO] Confidence: {confidence_threshold}\n")
#      11 try:
# ---> 12     run_annotation(dataset_root, model_path, confidence, to_annotate_path, auto_annotated_path, mapping_file_path)
#      13 except FileNotFoundError as e:
#      14     print(str(e))
#
# NameError: name 'confidence' is not defined
